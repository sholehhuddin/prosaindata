# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
SERVER = 'Server'
DATABASE = 'prosain200411100120_sepallength'
DRIVER = 'SQL Server Native Client 15.0'
USERNAME = 'postgres'
PASSWORD = 'sholeh841'
DATABASE_CONNECTION = f'mssql://{USERNAME}:{PASSWORD}@{SERVER}
# Out:
#   File "<ipython-input-3-bfa717d2f70c>", line 6
#     DATABASE_CONNECTION = f'mssql://{USERNAME}:{PASSWORD}@{SERVER}
#                                                                   ^
# SyntaxError: EOL while scanning string literal
