# %% [markdown]
# #**CRAWLING DATA TUGAS 1**
# Data crawling atau perayapan data adalah proses pengambilan data yang tersedia secara online untuk umum. Proses ini kemudian mengimpor informasi atau data yang telah ditemukan ke dalam file lokal di komputer Anda. Crawling dilakukan untuk ekstraksi data yang mengacu pada pengumpulan data dari worldwide web, dokumen, file, dan lain-lain. Proses pengambilan data akan terlihat seperti ini:
#
# 1. Crawler akan masuk ke target yang telah ditentukan, misalnya http://example.com,
# 2. Menemukan halaman produk.
# 3. Menemukan data spesifikasi produk (harga, judul, deskripsi, dan lain-lain).

# %% [markdown]
# **LIBRARY IMPORT**
#
# Library yang dibutuhan antara lain:
#
# 1. BeautifulSoup = library untuk mengcrawling data berita
# 2. snscrape = library untuk mengcrawling data twitter
# 3. pandas
# 4. CSV

# %%
# %pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import snscrape.modules.twitter as sntwitter
import pandas as pd
import csv

userAgent = {'user-agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Mobile Safari/537.36'}

# %% [markdown]
# ##Crawling data twitter##
# **snscrape**
#
# snscrape adalah pengikis untuk layanan jejaring sosial (SNS). Itu mengikis hal-hal seperti profil pengguna, tagar, atau pencarian dan mengembalikan item yang ditemukan, misalnya posting yang relevan.
#
# Layanan berikut saat ini didukung:
#
# Facebook: profil pengguna, grup, dan komunitas (alias posting pengunjung)
# Instagram: profil pengguna, tagar, dan lokasi
# Mastodon: profil pengguna dan toots (tunggal atau utas)
# Reddit: pengguna, subreddit, dan pencarian (via Pushshift)
# Telegram: saluran
# Twitter: pengguna, profil pengguna, tagar, pencarian, tweet (utas tunggal atau sekitarnya), daftar posting, dan tren
# VKontakte: profil pengguna
# Weibo (Sina Weibo): profil pengguna
#
# Untuk menggunakan Snscrape, Anda harus menginstal Python terlebih dahulu. Setelah itu, Anda dapat menginstal Snscrape dengan perintah “pip install snscrape” di terminal. Kemudian, untuk melakukan crawling data Twitter, Anda dapat menjalankan perintah Snscrape di terminal dengan argumen yang sesuai dengan kebutuhan Anda.

# %%
import re

# tweets = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Anies Baswedan Calon Presiden since:2022-01-01 until:2023-02-20').get_items()):
    if i > 2000:
        break
    with open('data-twitter.csv', 'a') as file:
      wr = csv.writer(file, delimiter=',')
      wr.writerow([tweet.date, tweet.user.username, tweet.content])
# tweets_df = pd.DataFrame(tweets, columns=['Datetime', 'Username Twitter', 'Tweet'])
# Out:
# <ipython-input-3-596cd8b4a89a>:9: FutureWarning: content is deprecated, use rawContent instead
#   wr.writerow([tweet.date, tweet.user.username, tweet.content])

# %% [markdown]
# ##Crawliing Jurnal di pta-trunojoyo.ac.id
#
# Crawling data web dengan Beautiful Soup adalah teknik untuk mengekstrak data dari halaman web dengan menggunakan library Python yang bernama Beautiful Soup. Beautiful Soup menyediakan cara yang mudah untuk menavigasi struktur HTML dan XML dari halaman web, sehingga memungkinkan kita untuk mengambil data yang kita butuhkan.
#
# Pertama-tama, kita harus memuat halaman web yang ingin kita ambil datanya menggunakan library Python seperti requests. Setelah itu, kita dapat menggunakan Beautiful Soup untuk melakukan parsing halaman web tersebut dan mengambil data yang kita butuhkan, seperti teks, gambar, link, dan sebagainya. Beautiful Soup juga dapat digunakan untuk melakukan filtering data berdasarkan kriteria tertentu, seperti tag HTML atau atributnya.
#
# Dalam praktiknya, proses crawling data web dengan Beautiful Soup melibatkan beberapa tahapan seperti mengakses URL, memuat halaman web, melakukan parsing, mengambil data, dan menyimpannya ke dalam format yang sesuai. Meskipun teknik ini relatif mudah dipelajari, namun penting untuk diingat bahwa crawling data web juga memiliki beberapa risiko dan batasan terkait dengan etika, keamanan, dan privasi data.

# %%
a = 1
for page in range(130, 170):
  url = f'https://pta.trunojoyo.ac.id/c_search/byprod/10/{page}'
  ge = req.get(url,userAgent).text
  sop = bs(ge, 'lxml')
  pd = sop.find('div',{'id':'begin'}).find('h2').text
  prodi = ''.join(pd).replace('Journal Jurusan','')
  li = sop.find('ul', class_='items list_style')
  lin = li.find_all('li')
  for x in lin:
    link = x.find('a', class_ ='gray button')['href']
    headline = x.find('div').find('a').text
    headline_ = ''.join(headline).replace('\n','')
    ge_ = req.get(link,userAgent).text
    sop_ = bs(ge_,'lxml')
    nim = x.find('div',{'style':'margin: 25px 0px 15px 0px;'}).find('a', class_='gray button')['href']
    nim_ = ''.join(nim).replace('https://pta.trunojoyo.ac.id/welcome/detail/','')
    content = sop_.find_all('ul', class_='items list_style')
    for x in content:
      nm = x.find('div',{'style':'padding:2px 2px 2px 2px;'}).find('span').text
      nama = ''.join(nm).replace('Penulis : ','')
      x = x.find_all('p')
      y = [y.text for y in x]
      content_ = ''.join(y).replace('\n','')
      print(f'done[{a}] >> {nim_[0:]}')
      a += 1
      with open('pta-trunojoyo.csv', 'a') as file:
        wr = csv.writer(file, delimiter=',')
        wr.writerow([nim_,nama,headline,content_,prodi])
# Out:
# done[1] >> 110411100064
# done[2] >> 110411100097
# done[3] >> 130411100064
# done[4] >> 120411100107
# done[5] >> 100411100060
# done[6] >> 120411100105
# done[7] >> 110411100045
# done[8] >> 140411100073
# done[9] >> 140411100128
# done[10] >> 140411100050
# done[11] >> 140411100024
# done[12] >> 140411100022
# done[13] >> 140411100102
# done[14] >> 110411100019
# done[15] >> 110411100040
# done[16] >> 140411100071
# done[17] >> 140411100092
# done[18] >> 130411100008
# done[19] >> 140411100100
# done[20] >> 140411100091
# done[21] >> 140411100074
# done[22] >> 140411100084
# done[23] >> 120411100022
# done[24] >> 140411100130
# done[25] >> 140411100119
# done[26] >> 140411100142
# done[27] >> 140411100052
# done[28] >> 120411100090
# done[29] >> 140411100098
# done[30] >> 140411100060
# done[31] >> 140411100093
# done[32] >> 120411100018
# done[33] >> 140411100075
# done[34] >> 140411100056
# done[35] >> 140411100029
# done[36] >> 140411100140
# done[37] >> 140411100094
# done[38] >> 130411100015
# done[39] >> 140411100097
# done[40] >> 130411100006
# done[41] >> 130411100010
# done[42] >> 130411100091
# done[43] >> 130411100109
# done[44] >> 110411100007
# done[45] >> 120411100007
# done[46] >> 140411100116
# done[47] >> 140411200150
# done[48] >> 140411100104
# done[49] >> 120411100040
# done[50] >> 110411100018
# done[51] >> 110411100010
# done[52] >> 110411100056
# done[53] >> 140411100106
# done[54] >> 140411100126
# done[55] >> 140411100141
# done[56] >> 140411100146
# done[57] >> 140411100081
# done[58] >> 140411100063
# done[59] >> 140411100096
# done[60] >> 140411100013
# done[61] >> 140411100054
# done[62] >> 140411100088
# done[63] >> 130411100114
# done[64] >> 140411100041
# done[65] >> 140411100017
# done[66] >> 140411100010
# done[67] >> 140411100111
# done[68] >> 170411200130
# done[69] >> 170411200137
# done[70] >> 140411100087
# done[71] >> 140411100070
# done[72] >> 120411100083
# done[73] >> 140411100069
# done[74] >> 140411100011
# done[75] >> 140411100046
# done[76] >> 140411100080
# done[77] >> 140411100118
# done[78] >> 140411100117
# done[79] >> 140411100027
# done[80] >> 140411100020
# done[81] >> 140411100109
# done[82] >> 120411100050
# done[83] >> 140411100048
# done[84] >> 140411200151
# done[85] >> 140411100051
# done[86] >> 140411100085
# done[87] >> 130411100087
# done[88] >> 140411100061
# done[89] >> 120411100015
# done[90] >> 140411100103
# done[91] >> 130411100106
# done[92] >> 140411100044
# done[93] >> 140411100132
# done[94] >> 130411100098
# done[95] >> 130411100011
# done[96] >> 140411100145
# done[97] >> 120411100066
# done[98] >> 140411100124
# done[99] >> 120411100086
# done[100] >> 150411100016
# done[101] >> 150411100052
# done[102] >> 150411100058
# done[103] >> 150411100051
# done[104] >> 150411100001
# done[105] >> 150411100108
# done[106] >> 150411100106
# done[107] >> 150411100078
# done[108] >> 150411100112
# done[109] >> 150411100115
# done[110] >> 150411100091
# done[111] >> 150411100072
# done[112] >> 150411100066
# done[113] >> 150411100061
# done[114] >> 150411100043
# done[115] >> 150411100088
# done[116] >> 170411200135
# done[117] >> 150411100030
# done[118] >> 150411100045
# done[119] >> 140411100082
# done[120] >> 140411100090
# done[121] >> 140411100016
# done[122] >> 140411100137
# done[123] >> 140411100039
# done[124] >> 140411100025
# done[125] >> 140411100042
# done[126] >> 150411100041
# done[127] >> 170411200134
# done[128] >> 170411200133
# done[129] >> 150411100107
# done[130] >> 140411100057
# done[131] >> 150411100017
# done[132] >> 120411100048
# done[133] >> 150411100096
# done[134] >> 140411100009
# done[135] >> 160411200188
# done[136] >> 170411200129
# done[137] >> 140411100031
# done[138] >> 140411100034
# done[139] >> 140411100008
# done[140] >> 150411100021
# done[141] >> 150411100035
# done[142] >> 120411100072
# done[143] >> 170411200128
# done[144] >> 150411100070
# done[145] >> 140411100078
# done[146] >> 140411100143
# done[147] >> 150411100097
# done[148] >> 130411100093
# done[149] >> 150411100029
# done[150] >> 150411100013
# done[151] >> 150411100024
# done[152] >> 150411100027
# done[153] >> 150411100125
# done[154] >> 150411100068
# done[155] >> 150411100121
# done[156] >> 140411100065
# done[157] >> 140411100099
# done[158] >> 140411100043
# done[159] >> 140411100115
# done[160] >> 150411100033
# done[161] >> 140411100053
# done[162] >> 140411100028
# done[163] >> 150411100042
# done[164] >> 140411100120
# done[165] >> 150411100111
# done[166] >> 150411100055
# done[167] >> 150411100025
# done[168] >> 150411100005
# done[169] >> 150411100019
# done[170] >> 150411100074
# done[171] >> 140411100072
# done[172] >> 140411100032
# done[173] >> 130411100074
# done[174] >> 170411200138
# done[175] >> 150411100004
# done[176] >> 150411100031
# done[177] >> 150411100064
# done[178] >> 130411100082
# done[179] >> 130411100094
# done[180] >> 150411100124
# done[181] >> 130411100046
# done[182] >> 150411100123
# done[183] >> 150411100059
# done[184] >> 150411100104
# done[185] >> 140411100045
# done[186] >> 150411100002
# done[187] >> 130411200123
# done[188] >> 130411100034
# done[189] >> 130411100086
# done[190] >> 130411100069
# done[191] >> 130411100053
# done[192] >> 150411100009
# done[193] >> 150411100040
# done[194] >> 150411100003
# done[195] >> 150411100015
# done[196] >> 150411100082
# done[197] >> 170411200127
# done[198] >> 170411200139
# done[199] >> 170411200126
# done[200] >> 150411100084

# %% [markdown]
# ##Crawling Data Berita Online di detik.com

# %%
a = 1
for page in range(0, 30):
  url = f'https://www.detik.com/search/searchall?query=sambo&siteid=2&sortby=time&page={page}'
  ge = req.get(url,userAgent).text
  sop = bs(ge, 'lxml')
  li = sop.find('div', class_='list media_rows list-berita')
  lin = li.find_all('article')
  for x in lin:
    link = x.find('a')['href']
    headline = x.find('a').find('h2').text
    ge_ = req.get(link,userAgent).text
    sop_ = bs(ge_,'lxml')
    content = sop_.find_all('div', class_='detail__body-text itp_bodycontent')
    for x in content:
      x = x.find_all('p')
      y = [y.text for y in x]
      content_ = ''.join(y).replace('\n','').replace('ADVERTISMENT','').replace('SCROLL TO RESUME CONTENT', '')
      print(f'done[{a}] >> {headline[0:]}')
      a += 1
      with open('beritaonline.csv', 'a') as file:
        wr = csv.writer(file, delimiter=',')
        wr.writerow([headline,content_])
# Out:
# done[1] >> Eliezer Tak Dipecat, Ortu Yosua Kecewa: Anak Saya Ditembak oleh Dia!
# done[2] >> Sidang Etik Putuskan Bharada Eliezer Tetap Jadi Polisi!
# done[3] >> Daftar Putusan Etik di Pusaran Kasus Yosua: Sambo Dipecat, Eliezer Sanksi Demosi
# done[4] >> Hasil Sidang Etik: Bharada Eliezer Tak Dipecat Polri!
# done[5] >> Putusan Sidang Etik: Bharada Eliezer Tetap Polisi!
# done[6] >> Tata Cara Sidang Kode Etik Polri, Begini Aturan dan Tahapannya
# done[7] >> Eliezer Tak Dipecat, Ortu Yosua Kecewa: Anak Saya Ditembak oleh Dia!
# done[8] >> Sidang Etik Putuskan Bharada Eliezer Tetap Jadi Polisi!
# done[9] >> Daftar Putusan Etik di Pusaran Kasus Yosua: Sambo Dipecat, Eliezer Sanksi Demosi
# done[10] >> Hasil Sidang Etik: Bharada Eliezer Tak Dipecat Polri!
# done[11] >> Putusan Sidang Etik: Bharada Eliezer Tetap Polisi!
# done[12] >> Tata Cara Sidang Kode Etik Polri, Begini Aturan dan Tahapannya
# done[13] >> Bharada Richard Eliezer Jalani Sidang Etik
# done[14] >> Vonis Eliezer Inkrah Hari Ini Jika Tak Ada Banding
# done[15] >> Pakai PDH Yanma, Begini Momen Bharada Richard Eliezer Jalani Sidang Etik
# done[16] >> Eliezer Jalani Sidang Etik Polri Hari Ini, 8 Saksi Dihadirkan
# done[17] >> Polri Berharap Sidang Etik Bharada Eliezer Tuntas Sore Ini
# done[18] >> 8 Orang Jadi Saksi Sidang Etik Bharada Richard Eliezer Hari Ini
# done[19] >> Richard Eliezer Menatap Hari Kebebasan yang Bakal Lebih Cepat
# done[20] >> Mahfud Ungkap Biang Kerok Indeks Persepsi Korupsi RI Anjlok: Birokrasi
# done[21] >> Richard Eliezer Bakal Bebas Lebih Cepat
# done[22] >> Pesan Ketua Banggar DPR untuk Dukung Agenda Reformasi Polri
# done[23] >> Elegi Vonis Eliezer
# done[24] >> Richard Eliezer Berstatus Justice Collaborator, Remisi Tambahan Disiapkan
# done[25] >> Balasan Kejagung ke Hotman soal Jaksa dari Kasus Sambo di Sidang Teddy
# done[26] >> Jaksa Banding Vonis Sambo dkk, Ini Alasannya
# done[27] >> TAMPAK Cabut Laporan terhadap Richard Eliezer di Propam Polri
# done[28] >> MA: Hampir Dapat Dipastikan Vonis Mati ke Ferdy Sambo Tak Ada Intervensi
# done[29] >> Hotman Tanya Identitas JPU Sidang Irjen Teddy: Saya Lihat Jaksa Kasus Sambo
# done[30] >> Heboh Ruang Sidang Didobrak Pengunjung Usai Eliezer Divonis Ringan
# done[31] >> Vonis Mati dan Perlawanan Ferdy Sambo
# done[32] >> Ayah Tuntut Nama Baik Yosua Dipulihkan dan Pangkat Naik
# done[33] >> Hakim yang Vonis Mati Ferdy Sambo Dikira Mertua Kiky Saputri
# done[34] >> Orang Tua Yosua Minta Nama Baik Anaknya Dipulihkan
# done[35] >> Divonis 1,5 Tahun, Segini Gaji &Tunjangan yang Diterima Bharada Richard Eliezer
# done[36] >> Ortu Yosua Tiba di Jambi Usai Hadiri Sidang Vonis Sambo Cs
# done[37] >> Ferdy Sambo Cs Dilaporkan Keluarga Brigadir Yosua Atas Dugaan Pencurian
# done[38] >> Hakim Eks KPT Denpasar yang Vonis Mati Sambo Punya Harta Rp 12 Miliar
# done[39] >> Gaji Terakhir yang Dinikmati Ferdy Sambo Sebelum Divonis Mati
# done[40] >> Rincian Harta Rp 12 M Hakim Wahyu Imam Santoso yang Vonis Mati Ferdy Sambo
# done[41] >> Babak Baru Sambo dkk Kini Dipolisikan soal Duit di ATM Yosua
# done[42] >> Upaya Ortu Harap Pangkat Yosua Naik Dua Tingkat
# done[43] >> Respons Ketus Keluarga Yosua Dengar Ferdy Sambo Cs Banding Vonis Hakim
# done[44] >> Bagaimana Pelaksanaan Hukuman Mati di Indonesia? Ini 4 Tahapannya!
# done[45] >> Kata Ayah Yosua Soal Peluang Eliezer Balik ke Brimob
# done[46] >> Perlindungan bagi Bharada Eliezer Belum Selesai
# done[47] >> Jaksa Juga Ajukan Banding atas Vonis Ferdy Sambo dkk
# done[48] >> Ortu Minta Pangkat Yosua Naik Jadi Aipda-Rumah Sambo Jadi Museum
# done[49] >> Analisis Pakar Unpar Atas Vonis 1,5 Tahun Penjara Bagi Eliezer
# done[50] >> LPSK Ungkap Putri Candrawathi Tak Pernah Ajukan Diri Jadi JC
# done[51] >> Bharada E Ajukan Perpanjangan Justice Collaborator ke LPSK
# done[52] >> Sambo, Putri dan Ricky Dilaporkan soal Dugaan Pencurian Uang-Laptop Yosua
# done[53] >> Sambo Cs Ajukan Banding, Keluarga Yosua: Bukan Urusan Kita
# done[54] >> Datangi Bareskrim, Ortu Minta Pangkat Yosua Naik 2 Tingkat Jadi Aipda
# done[55] >> Kini Dipolisikan, Urusan Rp 200 Juta di ATM Yosua Pernah Muncul di Sidang
# done[56] >> Sambo hingga Putri Resmi Banding, Ayah Brigadir Yosua: Itu Hak Mereka
# done[57] >> Vonis Sambo hingga Putri Candrawathi Dapat Berubah, Eliezer Sudah Inkrah
# done[58] >> Divonis Mati, Ferdy Sambo Dijerat Pakai KUHP Lama atau Baru?
# done[59] >> Kuat Ma'ruf-Ricky Rizal Protes Vonis Eliezer Hanya 1 Tahun 6 Bulan Bui
# done[60] >> Apa Arti Inkrah dalam Hukum Seperti Vonis Eliezer?
# done[61] >> Vonis Eliezer Inkrah, Hukuman Sambo hingga Putri Candrawathi Bisa Berubah
# done[62] >> Jaksa Tak Banding, Hukuman 1,5 Tahun Bharada Eliezer Inkrah!
# done[63] >> Ferdy Sambo Cs Ajukan Banding, Apa itu?
# done[64] >> Kata Pakar soal Motif Pembunuhan Yosua Bisa Bebaskan Richard Eliezer
# done[65] >> Fakta dan Bukti di Sidang Sambo Dkk Jadi Perhatian Jokowi
# done[66] >> Vonis Ringan Eliezer Diapresiasi Sana-sini tapi Diprotes Kuat-Ricky
# done[67] >> Usai Divonis 1,5 Tahun Penjara, Bharada Eliezer Segera Disidang Etik
# done[68] >> Ramai-ramai Bantah KUHP Baru Demi Loloskan Sambo dari Hukuman Mati
# done[69] >> Kapolri soal Bharada Eliezer Kembali ke Brimob: Peluang Itu Ada
# done[70] >> Ketua LPSK Sampaikan 2 Pesan Richard Eliezer Usai Divonis 1,5 Tahun
# done[71] >> Jaksa Tak Ajukan Banding Vonis Eliezer karena Keluarga Yosua Sudah Ikhlas
# done[72] >> Kejagung Tak Ajukan Banding Vonis Ringan Eliezer, Pengacara: Ini Mukjizat
# done[73] >> Divonis Hukuman Mati, Ferdy Sambo Ajukan Banding
# done[74] >> Ferdy Sambo-Putri-Kuat dan Ricky Ajukan Banding
# done[75] >> Ferdy Sambo cs Resmi Banding, Begini Respons Kejagung
# done[76] >> Jokowi Tegaskan Pemerintah Tak Intervensi Vonis Sambo hingga Eliezer
# done[77] >> Sambo-Putri-Kuat-Ricky Kompak Ajukan Banding!
# done[78] >> Pakar Hukum Unima Nilai Motif Pembunuhan Yosua Seharusnya Diungkap
# done[79] >> Daftar Hal yang Meringankan Richard Eliezer Hingga Divonis 1,5 Tahun
# done[80] >> Mengapa Eliezer Dihukum Ringan? Ini Hal-hal Meringankan di Vonis
# done[81] >> Kejagung Bicara soal Spekulasi Nasib Vonis Mati Sambo dan KUHP Baru
# done[82] >> Vonis Sambo, Citra Hakim, dan "Public Trust"
# done[83] >> Kejagung Ungkap Alasan Jaksa Tak Ajukan Banding Vonis 1,5 Tahun Eliezer
# done[84] >> Jaksa Tak Banding, Vonis 1,5 Tahun Bui Eliezer Berkekuatan Hukum Tetap
# done[85] >> Kejagung Jawab Spekulasi KUHP Baru dan Nasib Vonis Mati Sambo
# done[86] >> Kejagung Tak Akan Ajukan Banding Vonis 1 Tahun 6 Bulan Eliezer
# done[87] >> Alasan Jaksa Tak Banding Vonis Eliezer: Sudah Terwujud Keadilan
# done[88] >> Kejagung Tak Ajukan Banding Vonis Eliezer: Kami Mewakili Korban
# done[89] >> Kejagung Tak Ajukan Banding Vonis Ringan Richard Eliezer
# done[90] >> Sambo Dipidana Mati, Semua "Happy"
# done[91] >> Cara Mengajukan Permohonan Perlindungan ke LPSK Seperti Eliezer
# done[92] >> Jokowi soal Vonis Sambo hingga Eliezer: Semua Harus Menghormati
# done[93] >> Nasib Karier Bharada Eliezer di Polri Ditentukan Dalam Sidang Etik
# done[94] >> Ketua Komisi III DPR Tanggapi Kemungkinan KUHP Baru Berlaku di Vonis Sambo
# done[95] >> Status Justice Collaborator di Balik Vonis Ringan Richard Eliezer
# done[96] >> Tegaskan Tak Ikut Campur, Jokowi Soroti Fakta dan Saksi di Vonis Sambo dkk
# done[97] >> Yasonna soal KUHP Baru demi Loloskan Sambo dari Vonis Mati: Gila Aja Mikirnya
# done[98] >> Nasib Eliezer Sebagai Anggota Polri Akan Diputuskan Lewat Sidang Etik
# done[99] >> GMKI: Vonis Eliezer Pelajaran agar Junior Tak Perlu Ikuti Senior Jahat
# done[100] >> Kuat Ma'ruf Bandingkan Vonisnya dengan Eliezer: Tidak Adil!
# done[101] >> Eliezer Masih Dilindungi LPSK, Sampai Kapan?
# done[102] >> Ultra Petita Vonis Sambo
# done[103] >> Kuat Ma'ruf 'Iri' dengan Vonis Eliezer, Merasa Hakim Tak Adil
# done[104] >> Polri Pertimbangkan Status JC dan Masukan Publik soal Nasib Karier Eliezer
# done[105] >> Kuat Ma'ruf Anggap Vonis Ringan Eliezer Tak Adil
# done[106] >> Bandingkan Vonisnya dengan Eliezer, Kuat Ma'ruf Merasa Tidak Adil
# done[107] >> Harapan ke Jaksa Agar Tak Ajukan Banding Usai Richard Eliezer Divonis Ringan
# done[108] >> Vonis Sambo, Hukuman Mati, dan KUHP Baru
# done[109] >> Harapan Besar Eliezer Usai Divonis 1,5 Tahun: Kembali ke Brimob Polri
# done[110] >> Eliezer Harap Jaksa Tak Ajukan Banding Vonis, PKB Bicara Independensi
# done[111] >> Kata Kompolnas soal Eliezer Divonis 1,5 Tahun Penjara
# done[112] >> Penjelasan Ahli Hukum Soal Peluang Ferdy Sambo Menang di Tingkat Banding
# done[113] >> Fakta-fakta Vonis Richard Eliezer Jauh Lebih Ringan dari Tuntutan Jaksa
# done[114] >> Mahfud: Hukuman Mati Jadi Seumur Hidup Bui Ada di RKUHP Sebelum Kasus Sambo
# done[115] >> Alasan Hakim Tetapkan Eliezer Sebagai Justice Collaborator Kasus Yosua
# done[116] >> Wamenkumham Jawab Kekhawatiran Jual Beli Surat Kelakuan Baik soal Hukuman Mati
# done[117] >> Maaf Tulus Ortu Yosua di Balik Vonis Ringan Eliezer
# done[118] >> Sampai Kapan Eliezer Dapat Perlindungan LPSK Sebagai Justice Collaborator?
# done[119] >> Tangis Tante Yosua yang Tak Terima Vonis Rendah Richard Eliezer
# done[120] >> 6 Hal Meringankan Eliezer hingga Divonis Ringan di Kasus Pembunuhan Yosua
# done[121] >> Maaf dari Keluarga Yosua di Balik Vonis Ringan Eliezer
# done[122] >> Alasan Keluarga Baru Laporkan Ferdy Sambo cs soal Hilangnya Uang Yosua
# done[123] >> DPR Sentil Balik Hotman Paris Soal Hukuman Mati jadi Seumur Hidup
# done[124] >> Sambo Divonis Mati, Wapres: Itu Hak Pengadilan, Pemerintah Tak Intervensi
# done[125] >> Laporkan Sambo Cs ke Polisi, Ibu Yosua Minta Barang-barang Anaknya
# done[126] >> Keluarga Yosua Kini Laporkan Ferdy Sambo soal Pencurian Uang!
# done[127] >> Tante Yosua Merasa Vonis 1,5 Tahun Eliezer Tidak Adil
# done[128] >> Wamenkumham Tepis Prasangka Buruk KUHP Baru Disiapkan untuk Ferdy Sambo
# done[129] >> Keluarga Bakal Jenguk Richard Eliezer di Rutan Bareskrim Besok
# done[130] >> Eddy Hiariej Jelaskan KUHP Baru Bisa Dipakai Ferdy Sambo Bila Masuk 2026
# done[131] >> Ibu Eliezer: Terima Kasih Orang Tua Yosua, Sudah Terima Maaf Icad
# done[132] >> Ibunda: Vonis Ringan Richard Eliezer Tak Lepas dari Doa Para Pendukung
# done[133] >> Wapres soal Vonis Mati Ferdy Sambo: Haknya Pengadilan
# done[134] >> Analisis Pakar Hukum Unsoed tentang Vonis Sambo hingga Eliezer
# done[135] >> Harapan agar Jaksa Tak Banding Usai Eliezer Divonis Bui 18 Bulan
# done[136] >> Arsul Sani: Hukuman Mati Jadi Seumur Hidup Pakai Keputusan Presiden
# done[137] >> Sorak-sorai Pengunjung Sidang Eliezer hingga Pintu Sidang Didobrak
# done[138] >> Ibu Eliezer Berterima Kasih ke Orang Tua Yosua yang Terima Maaf Anaknya
# done[139] >> Vonis Hakim di Kasus Brigadir Yosua Dinilai Pulihkan Kepercayaan Publik
# done[140] >> Hakim Tolak Semua Pembelaan Ferdy Sambo dkk di Kasus Pembunuhan Yosua
# done[141] >> Ibu Richard Eliezer: Ada Harapan Icad Tetap Jadi Anggota Brimob
# done[142] >> Alasan Eliezer Tak Mau Ortunya Hadiri Sidang Vonis: Tak Mau Bikin Sedih
# done[143] >> Ibu Yosua Terima Vonis 1,5 Tahun Bui Eliezer Meski Jadi Eksekutor Penembakan
# done[144] >> Ma'ruf Amin: Vonis Mati Sambo Hak Pengadilan, Pemerintah Tak Intervensi
# done[145] >> Ibunda: Richard Eliezer Masih Semangat Lanjutkan Karier sebagai Polisi
# done[146] >> Gatot Tak Berpikir Jadi Capres-Cawapres, Amien Rais: Dia Belum Semangat
# done[147] >> Pengacara Eliezer ke Jaksa: Jangan Bandinglah
# done[148] >> Datangi Polres Jaksel, Ortu Lapor soal Raibnya Duit di ATM Brigadir Yosua
# done[149] >> Eliezer Harap Bisa Dinas di Brimob Lagi Usai Divonis 1,5 Tahun Bui
# done[150] >> Jaksa Diharap Tak Ajukan Banding Vonis 1,5 Tahun Penjara Richard Eliezer
# done[151] >> Mahfud Md soal Vonis Sambo dkk: Jangan Dikira Bahwa Jaksa Itu Gagal
# done[152] >> Momen Sigap LPSK Kawal Eliezer saat Pengunjung Dobrak Ruang Sidang
# done[153] >> Richard Eliezer Dihukum Berapa Tahun? Ini Putusan Hakim
# done[154] >> Analisis Vonis Sambo dkk yang Berbanding Terbalik dari Tuntutan Jaksa
# done[155] >> Para Artis Ikut Merinding Eliezer Divonis 1,5 Tahun Bui Kasus Pembunuhan Yosua
# done[156] >> Eliezer Divonis 1,5 Tahun Bui, Komitmen Nikahi Tunangan Segera Terwujud
# done[157] >> Tante Yosua Menangis Dengar Vonis 1,5 Tahun Eliezer: Terlalu Rendah
# done[158] >> Ironi Tuntutan Jaksa Terhadap Sambo-Eliezer 'Dibalas' Telak Hakim
# done[159] >> Ferdy Sambo Divonis Mati, Moeldoko: Harapan Masyarakat Terpenuhi
# done[160] >> Mahfud soal Beda Tuntutan dan Vonis Sambo dkk: Itu soal Tafsir Saja
# done[161] >> Momen LPSK Kawal Eliezer Usai Vonis Saat Pengunjung Dobrak Ruang Sidang
# done[162] >> Pengacara Eliezer Harap Jaksa Tak Ajukan Banding Vonis 1,5 Tahun Bui
# done[163] >> Eliezer Divonis 1,5 Tahun, Legislator PDIP Harap Jaksa Tidak Banding
# done[164] >> Tunangan Eliezer Kini Tak Perlu Lagi Menunggu Lama
# done[165] >> Eliezer Divonis 1,5 Tahun Bui, LPSK Berharap Jaksa Tak Banding
# done[166] >> Hakim Ungkap Hal Meringankan dan Memberatkan Vonis 1,5 Tahun Bui Eliezer
# done[167] >> Bagaimana Nasib Karier Eliezer di Polri Usai Divonis 1,5 Tahun Bui?
# done[168] >> Momen Keluarga Yosua Maafkan Eliezer Berujung Vonis Ringan
# done[169] >> Richard Eliezer Divonis 18 Bulan Bui, Bisa Bebas Februari 2024?
# done[170] >> Bharada Eliezer Divonis 1,5 Tahun Penjara, Begini Nasibnya di Polri
# done[171] >> Hakim: Eliezer Buat Terang Kasus Pembunuhan Yosua Meski Bahayakan Jiwa
# done[172] >> Ungkapan Haru Ibu Yosua: Walau Eliezer Hunjam Anakku Timah Panas...
# done[173] >> Vonis Sambo dan Putri Ultra Petita, Eliezer Jauh di Bawah Tuntutan
# done[174] >> Bharada Eliezer Justice Collaborator, LPSK Harap Jaksa Tak Banding
# done[175] >> Vonis Hakim 1,5 Tahun ke Eliezer Dinilai Sudah Proporsional
# done[176] >> Tangis Histeris-Sujud Keluarga Dengarkan Vonis Richard Eliezer 1,5 Tahun
# done[177] >> Vonis Ringan Eliezer, Hakim: Bekerja Sama dan Dimaafkan Keluarga Yosua
# done[178] >> Polri Angkat Bicara soal Karier Richard Eliezer Usai Divonis 1,5 Tahun Bui
# done[179] >> Hakim: Richard Eliezer Tembak Yosua, tapi Bukan Pelaku Utama
# done[180] >> Daftar Lengkap Vonis Terdakwa Pembunuhan Berencana Brigadir Yosua
# done[181] >> Ibu Yosua: Walau Eliezer Hunjam Anakku Timah Panas, Saya Percaya Vonis Hakim
# done[182] >> Video Eliezer Divonis 1,5 Tahun Bui di Kasus Pembunuhan Yosua
# done[183] >> Daftar Vonis Pembunuhan Yosua: Sambo Dihukum Mati, Eliezer 1,5 Tahun Bui
# done[184] >> Penggemar Rayakan Vonis 1,5 Tahun Bui Richard Eliezer, Puji Keputusan Hakim
# done[185] >> Hal Meringankan Vonis Eliezer: Masih Muda dan Dimaafkan Keluarga Yosua
# done[186] >> Pengunjung Sidang Dobrak Ruang Sidang Usai Vonis Ringan Eliezer
# done[187] >> Momen Fans Nyanyikan Indonesia Raya Usai Eliezer Divonis 1,5 Tahun Bui
# done[188] >> Wakil Ketua Komisi III DPR Anggap Vonis 1,5 Tahun Eliezer Adil
# done[189] >> Kelanjutan Karier Bharada Eliezer di Polri Setelah Divonis 1,5 Tahun
# done[190] >> Bharada Eliezer Divonis 1,5 Tahun, Dipecat Polri?
# done[191] >> Hal Memberatkan Vonis Eliezer: Hubungan Akrab dengan Yosua Tak Dihargai
# done[192] >> Eliezer Divonis 1,5 Tahun, Keluarga Sampaikan Terima Kasih ke Hakim
# done[193] >> Kondisi Berantakan Ruang Sidang Usai Didobrak Pengunjung Sidang Eliezer
# done[194] >> Hakim Bicara Tekanan Psikis dalam KUHP Baru di Sidang Vonis Eliezer
# done[195] >> Tangis Haru Richard Eliezer Usai Divonis 1,5 Tahun Bui
# done[196] >> Adu Perspektif: Antara Vonis Sambo dan Rasa Keadilan
# done[197] >> Fans Nyanyikan Lagu Indonesia Raya Usai Eliezer Divonis 1,5 Tahun Penjara
# done[198] >> Eliezer Divonis 1,5 Tahun, Jauh di Bawah Tuntutan 12 Tahun Penjara
# done[199] >> Bharada E Divonis 1,5 Tahun Bui, Bagaimana Nasib Kariernya di Polri?
# done[200] >> Eliezer Divonis 1,5 Tahun Bui, Hakim: Tak Ada Alasan Pembenar Maupun Pemaaf
# done[201] >> Sorak Sorai Fans Usai Eliezer Divonis 1,5 Tahun Bui, Langsung Puji Hakim
# done[202] >> Justice Collaborator Dikabulkan, Richard Eliezer Divonis 1,5 Tahun!
# done[203] >> Tangis Richard Eliezer Usai Dijatuhi Vonis 1,5 Tahun
# done[204] >> Hakim Kabulkan Status Justice Collaborator Richard Eliezer
# done[205] >> Jejak Eliezer Bongkar Skenario Pembunuhan Yosua hingga Divonis 1,5 Tahun Bui
# done[206] >> Vonis Eliezer Jauh di Bawah Tuntutan, dari 12 Tahun Jadi 1,5 Tahun Bui
# done[207] >> Hakim Sebut Ferdy Sambo Tembak Kepala Yosua!
# done[208] >> Vonis 1,5 Tahun Bui Bagi Bharada Eliezer!
# done[209] >> Pengunjung Dobrak Ruang Sidang dan Heboh Usai Vonis 1,5 Tahun Bui Eliezer
# done[210] >> Bharada Richard Eliezer Menangis Usai Divonis 1,5 Tahun Penjara
# done[211] >> Bharada Richard Eliezer Divonis 1,5 Tahun, Segini Gaji yang Diterima
# done[212] >> Oma-oma Fans Eliezer ke PN Jaksel, Ada dari Purwokerto hingga Belitung
# done[213] >> Richard Eliezer Divonis 1,5 Tahun Bui!
# done[214] >> Richard Eliezer Divonis 1,5 Tahun Penjara di Kasus Pembunuhan Yosua
# done[215] >> Justice Collaborator Richard Eliezer Dikabulkan Hakim!
# done[216] >> TOK! Bharada Richard Eliezer Divonis 1 Tahun 6 Bulan Penjara
# done[217] >> Hakim: Tidak Ditemukan Alasan Pembenar Maupun Pemaaf ke Eliezer
# done[218] >> Bharada Richard Eliezer Divonis 1,5 Tahun Penjara!
# done[219] >> Hakim: Perintah Bunuh Yosua dari Sambo ke Eliezer Bukan Perintah Jabatan
# done[220] >> Hakim: Betapa Kejamnya Sambo, Musuh Menyerah Tak Boleh Dibunuh
# done[221] >> Keluarga Yosua di Jambi Serahkan Vonis Eliezer ke Hakim: Kesal Tapi Dia JC
# done[222] >> Eliezer Punya Kesempatan Tidak Tembak Bagian Vital Yosua tapi Tak Dilakukan
# done[223] >> Hakim: Tembakan Ferdy Sambo Tembus Kepala Yosua!
# done[224] >> Hakim Nyatakan Richard Eliezer Terbukti Ikut Rencanakan Pembunuhan Yosua
# done[225] >> Hakim: Sikap Batin Eliezer Tunjukkan Kesengajaan agar Yosua Meninggal
